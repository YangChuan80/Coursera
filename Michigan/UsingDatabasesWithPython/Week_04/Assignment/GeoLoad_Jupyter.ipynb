# %%
import urllib
import sqlite3
import json
import time
import ssl

serviceurl = "http://maps.googleapis.com/maps/api/geocode/json?"

# Deal with SSL certificate anomalies Python > 2.7
# scontext = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
scontext = None

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 : break
    address = line.strip()
    print ''
    cur.execute("SELECT geodata FROM Locations WHERE address= ?", (buffer(address), ))

    try:
        data = cur.fetchone()[0]
        print "Found in database ",address
        continue
    except:
        pass

    print 'Resolving', address
    url = serviceurl + urllib.urlencode({"sensor":"false", "address": address})
    print 'Retrieving', url
    uh = urllib.urlopen(url, context=scontext)
    data = uh.read()
    print 'Retrieved',len(data),'characters',data[:20].replace('\n',' ')
    count = count + 1
    try: 
        js = json.loads(str(data))
        # print js  # We print in case unicode causes an error
    except: 
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') : 
        print '==== Failure To Retrieve ===='
        print data
        break

    cur.execute('''INSERT INTO Locations (address, geodata) 
            VALUES ( ?, ? )''', ( buffer(address),buffer(data) ) )
    conn.commit() 
    time.sleep(1)

print "Run geodump.py to read the data from the database so you can visualize it on a map."
# Out:
# Found in database  Northeastern University
#
# Found in database  University of Hong Kong, Illinois Institute of Technology, Bradley University
#
# Found in database  Technion
#
# Found in database  Viswakarma Institute, Pune, India
#
# Found in database  UMD
#
# Found in database  Tufts University
#
# Found in database  Monash University
#
# Found in database  Kokshetau Institute of Economics and Management
#
# Found in database  RSU named S.A. Esenin
#
# Found in database  Tavrida National V.I. Vernadsky University
#
# Found in database  UOC
#
# Found in database  Irkutsk State University
#
# Found in database  Institute of Technology Telkom
#
# Found in database  Shanghai Jiao Tong University
#
# Found in database  University of Ilorin, Kwara State. Nigeria
#
# Found in database  Monash University Churchill Australia
#
# Found in database  UNISA
#
# Found in database  Fachhochschule FH Salzburg
#
# Found in database  Tampere University of Technology (Tampere, Finland)
#
# Found in database  Saint Petersburg State University
#
# Found in database  University of São Paulo
#
# Found in database  Smolensk State University (Russia)
#
# Found in database  Institute of Business Administration, Karachi
#
# Found in database  universidad complutense de madrid
#
# Found in database  Masdar Institute
#
# Found in database  University of London
#
# Found in database  University of Oxford
#
# Found in database  Tallinn University of Technology
#
# Found in database  University of Tartu
#
# Found in database  University of Padua
#
# Found in database  University of Pune, India
#
# Found in database  National Kyiv Shevchenko University
#
# Found in database  UC Berkeley
#
# Found in database  University of Wisconsin - Madison
#
# Found in database  Lodz University of Technology
#
# Found in database  NRU IFMO
#
# Found in database  Dniepropetrovsk National University (Ukraine), Applied Math Faculty
#
# Found in database  Dokuz Eylul University, Izmir, Turkey
#
# Found in database  Beijing normal university
#
# Found in database  University of Piraeus, Athens
#
# Found in database  Universidad de Buenos Aires (UBA). Argentina.
#
# Found in database  SASTRA University
#
# Found in database  Nagpur University
#
# Found in database  Duke University
#
# Found in database  San Francisco State University
#
# Found in database  FATEC-SP - Faculdade de Tecnologia do Estado de São Paulo
#
# Found in database  University of Texas at Austin
#
# Found in database  University of applied sciense of Mikkeli (Finland)
#
# Found in database  Troy University
#
# Found in database  Universidade do Minho
#
# Found in database  National University of Sciences and Technology (NUST)-Pakistan
#
# Found in database  Pontificia universidad catolica de chile
#
# Found in database  Illinois State University Joliet Junior College
#
# Found in database  American University in Cairo (AUC)
#
# Found in database  Obninsk Technical University of Nuclear Power Engineering, Russia
#
# Found in database  Vyatka State Humanitarian University
#
# Found in database  Weizmann Institute of Science (Israel)
#
# Found in database  University of Washington
#
# Found in database  Kharkiv State Academy of Municipal Economy, Ukraine
#
# Found in database  Faculty of Electrical Engineering in Sarajevo, University of Sarajevo
#
# Found in database  Universidad de Los Andes Colombia
#
# Found in database  University of Colorado at Boulder
#
# Found in database  Magnitogorsk State Technical University
#
# Found in database  USC
#
# Found in database  Simon Fraser University
#
# Found in database  Columbia University (New York)
#
# Found in database  University of Southern California
#
# Found in database  University of Warsaw
#
# Found in database  Warsaw University of Technology
#
# Found in database  (Some place in New Zealand you haven't heard of.)
#
# Found in database  Massey university part-time Distance learning
#
# Found in database  University of Oklahoma
#
# Found in database  University of Pavia, Italy
#
# Found in database  University of Missouri - Columbia
#
# Found in database  Czech Technical University in Prague
#
# Found in database  Illinois Institute of Technology
#
# Found in database  Penn State University
#
# Found in database  University of Utah
#
# Found in database  Faculty of Science, University of Zagreb - Department of Mathematics
#
# Found in database  Universitat Politecnica de Valencia
#
# Found in database  University of Vienna
#
# Found in database  University of Puerto Rico - Mayaguez Campus
#
# Found in database  University "Hyperion" of Bucharest
#
# Found in database  University of New Haven
#
# Found in database  University of Washington -Bothell
#
# Found in database  Drexel University
#
# Found in database  University of Texas at Austin
#
# Found in database  University of Helsinki
#
# Found in database  University of Michigan
#
# Found in database  Carnegie Mellon University
#
# Found in database  Kazan Federal University
#
# Found in database  Pondicherry University
#
# Found in database  Far-Eastern State University
#
# Found in database  Nanyang Technological University
#
# Found in database  Slovak University of Technology
#
# Found in database  NYU
#
# Found in database  UFABC - Universidade Federal do ABC, Sanso André - SP - Brazil
#
# Found in database  University of Debrecen
#
# Found in database  California State University, San Bernardino
#
# Found in database  National University "Kyiv-Mohyla Academy" (Kyiv, Ukraine)
#
# Found in database  Laurentian University
#
# Found in database  Humanities Institute of TV and Radio, Moscow, Russia
#
# Found in database  University of Cambridge, UK
#
# Found in database  Payame Noor University, Tehran, Iran
#
# Found in database  Middle East Technical University
#
# Found in database  EPFL
#
# Found in database  Faculty of Technical Sciences, Novi Sad, Serbia
#
# Found in database  University of Gothenburg, Sweden
#
# Found in database  Polytechnic University of Timisoara
#
# Found in database  University of Hawaii (Go, Rainbows!)
#
# Found in database  Belarusian State University
#
# Found in database  Haaga-Helia university of applied sciences
#
# Found in database  JADAVPUR UNIVERSITY
#
# Found in database  Gauhati University, India
#
# Found in database  Universidad de Buenos Aires
#
# Found in database  Università degli Studi di Genova, Genova, Italia
#
# Found in database  King Mongkut's University of Technology Thonburi
#
# Found in database  Universidad de la Sabana, Chia, Colombia
#
# Found in database  State University of New York (SUNY) College at Oswego
#
# Found in database  Kyrgyz Slavic Russian University
#
# Found in database  De La Salle University http://www.dlsu.edu.ph
#
# Found in database  Jawaharlal Nehru Technological University, INDIA
#
# Found in database  UCL (Université Catholique de Louvain) in Belgium
#
# Found in database  Boston University
#
# Found in database  The University of Manchester
#
# Found in database  Fachhochschule Düsseldorf
#
# Found in database  Pine Manor College (AA), Harvard University (BA), Lesley University (MEd)
#
# Found in database  Simón Bolívar University
#
# Found in database  Indiana University at Bloomington
#
# Found in database  RPI
#
# Found in database  University of Ottawa, Canada
#
# Found in database  Ural Federal University
#
# Found in database  BITS Pilani
#
# Found in database  Transilvania University
#
# Found in database  IIT(BHU), Varanasi, India
#
# Found in database  EM Lyon
#
# Found in database  Universidad Central de Venezuela
#
# Found in database  NTUU "KPI"
#
# Found in database  Universidade Federal da Paraiba, Brazil
#
# Found in database  Budapest University of Technology and Economics
#
# Found in database  Moscow Institute of Physics & Technology (State University)
#
# Found in database  Saint Petersburg State University of Aerospace Instrumentation, Russia
#
# Found in database  North Central College, Naperville, IL
#
# Found in database  Tech. Uni. Denmark (DTU)
#
# Found in database  Stanford
#
# Found in database  "Politehnica" Timisoara
#
# Found in database  National University of Engineering
#
# Found in database  Monash
#
# Found in database  Federal University of Campina Grande (UFCG)
#
# Found in database  Universidade Federal do Rio Grande do Sul (UFRGS)
#
# Found in database  Universidad Nacional Autónoma de México
#
# Found in database  University of New South Wales Harvard Business School
#
# Found in database  University of Tehran
#
# Found in database  Old Dominion University
#
# Found in database  Kyiv Unisersity of Oriental Language
#
# Found in database  Babcock University
#
# Found in database  University of Essex
#
# Found in database  Kharkiv National University of Radio Electronics (Ukraine)
#
# Found in database  Kaunas Technology University
#
# Found in database  University of Buenos Aires
#
# Found in database  University of Jaffna.
#
# Found in database  R V College of Engineering, Bangalore, India for BE in Instrumentation Technology
#
# Found in database  Beloit College
#
# Found in database  UCLA
#
# Found in database  University of Chicago
#
# Found in database  University of Sciences and Technology of Oran. Mohamed Boudiaf (USTO-MB).
#
# Found in database  Zagazig University, Egypt
#
# Found in database  University of Alberta
#
# Found in database  Belorussian State University
#
# Found in database  Jones International University (online) Illinois State Univeristy
#
# Found in database  University of Florida
#
# Found in database  Too many to mention.
#
# Found in database  University of Kerala, India
#
# Found in database  Politecnico di Milano
#
# Found in database  Vilnius Gediminas Technical University
#
# Found in database  Madras university/ Bharthidasan University in India .
#
# Found in database  Universidade Tecnica de Lisboa - Instituto Superior Técnico
#
# Found in database  Does not apply.
#
# Found in database  Stellenbosch University
#
# Found in database  imt ghazIABAD INDIA
#
# Found in database  University of Pennsylvania
#
# Found in database  National Institute of Technology, Jalandhar (India)
#
# Found in database  Universidad ICESI
#
# Found in database  Virginia Tech
#
# Found in database  arizona state university
#
# Found in database  Universidad del Valle de Guatemala
#
# Found in database  Mykolas Romeris University, Vilnius, Lithuania
#
# Found in database  BSU
#
# Found in database  Distance Learning Center at the Technical University of Kaiserslautern in Germany
#
# Found in database  Ain shams university, Cairo, Egypt
#
# Found in database  Universidad Nacional de Colombia
#
# Found in database  Saint-Petersburg Polytechnic Univesity
#
# Found in database  NAIT (Northern Alberta Institute of Technology)
#
# Found in database  Wayne State took courses at U of M
#
# Found in database  Universidad Nacional, Costa Rica
#
# Found in database  Marietta College (Ohio) Northwestern University
#
# Found in database  Grandville
#
# Found in database  Portland State University, Oregon Institute of Technology
#
# Found in database  Malayer Azad University, Iran
#
# Found in database  Shengjing Hospital of China Medical University
#
# Found in database  Baylor College of Medicine
#
# Found in database  MD Anderson Cancer Center
#
# Resolving Houston Rice University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Houston+Rice+University
# Retrieved 2302 characters {    "results" : [
# Run geodump.py to read the data from the database so you can visualize it on a map.
